# %%
import numpy as np

# %%
import pandas as pd

# %%
mydata = pd.read_csv('CardioGoodFitness-1.csv') # Reading the dataset

# %%
mydata.head() # It gives the top 5 values of the table.
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
mydata.describe(include="all")   # It describes all the information about the dataset, like mean, median, unique value, frequent value, Top value, etc.
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
mydata.info() #It gives overall short description about the data in the .csv file.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.7+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000258FF5C0>,
# ...
#       dtype=object)

# %%
import seaborn as sns

# %%
sns.boxplot(x="Gender",y="Age",data=mydata)

# %%
pd.crosstab(mydata['Product'],mydata['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(mydata['Gender'],mydata['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Gender
# Female                46      30
# Male                  61      43

# %%
sns.countplot(x='Product',hue='Gender',data=mydata) # The countplot's main job is to count the parameter which is given, with regarding hue value.

# %%
pd.pivot_table(mydata, index=['Product','Gender'],columns=['MaritalStatus'],aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
# ...

# %%
pd.pivot_table(mydata,values='Income',index=['Product','Gender'],columns=['MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
sns.pairplot(mydata) # Thsese are correlation that are available between the data.

# %%
mydata['Age'].std()
# Out:
# 6.943498135399795

# %%
mydata['Age'].mean()
# Out:
# 28.788888888888888

# %%
mydata.hist(by='Gender',column='Income')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000002C249AC8>,
# ...
#       dtype=object)

# %%
mydata.hist(by='Product',column='Miles',)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000002C161400>,
# ...
#       dtype=object)

# %%
corr = mydata.corr() # This the correlation function, that is being used to find the correlation between the data

# %%
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
cov = mydata.cov() # This the covariation function, that is being used to find the covariation, which is the normalization form of Correlation.

# %%
cov
# Out:
#                     Age     Education        Usage      Fitness        Income  \
# Age           48.212166      3.149410     0.113470     0.406828  5.884446e+04
# Education      3.149410      2.614867     0.693172     0.636623  1.670472e+04
# Usage          0.113470      0.693172     1.176785     0.695469  9.303043e+03
# Fitness        0.406828      0.636623     0.695469     0.919429  8.467925e+03
# Income     58844.463439  16704.717815  9303.042582  8467.925388  2.724706e+08
# Miles         13.186530     25.770795    42.709808    39.073246  4.652654e+05
#
#                    Miles
# Age            13.186530
# Education      25.770795
# Usage          42.709808
# Fitness        39.073246
# Income     465265.361887
# Miles        2689.833489

# %%
sns.heatmap(corr,annot=True)

# %%
# Performing Linear Regression for this data

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()

# %%
y = mydata['Miles']

# %%
x = mydata[['Usage','Fitness']]

# %%
regr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regr.coef_
# Out:
# array([20.21486334, 27.20649954])

# %%
regr.intercept_
# Out:
# -56.74288178464859
